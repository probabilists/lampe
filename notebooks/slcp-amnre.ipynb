# %% [markdown]
# # SLCP with AMNRE

# %%
import numpy as np
import torch
import torch.nn as nn

from datetime import datetime

from lampe.simulators.slcp import SLCP
from lampe.nn import AMNRE, BCEWithLogitsLoss
from lampe.masks import UniformMask
from lampe.optim import AdamW, ReduceLROnPlateau
from lampe.train import SummaryWriter, Trainer, AMNREPipe
from lampe.mcmc import LRESampler
from lampe.plot import corner

# %%
now = datetime.now().strftime('%Y%m%d_%H%M%S')
writer = SummaryWriter(log_dir=f'runs/slcp/{now}')

# %% [markdown]
# ## Training

# %%
sim = SLCP().cuda()
train_loader = sim.iterable(batch_size=1024, length=256)
valid_loader = sim.iterable(batch_size=1024, length=32)

# %%
model = AMNRE(5, 8, embedding=nn.Flatten(-2), hidden_sizes=[256] * 5, activation='ELU')
model.train()
model.cuda()
# Out:
# AMNRE(
#   (net): MLP(
#     (0): Linear(in_features=18, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=256, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=256, out_features=256, bias=True)
#     (7): ELU(alpha=1.0)
#     (8): Linear(in_features=256, out_features=256, bias=True)
#     (9): ELU(alpha=1.0)
#     (10): Linear(in_features=256, out_features=1, bias=True)
#   )
#   (standardize): Identity()
#   (embedding): Flatten(start_dim=-2, end_dim=-1)
# )

# %%
pipe = AMNREPipe(model, mask_sampler=UniformMask(5).cuda(), criterion=BCEWithLogitsLoss())
optimizer = AdamW(model.parameters(), lr=1e-3, weight_decay=1e-3)
scheduler = ReduceLROnPlateau(optimizer, gamma=0.5, patience=7)
trainer = Trainer(pipe, train_loader, valid_loader, optimizer, scheduler, clip=1., writer=writer)

for epoch in trainer(64):
    pass  # something to do in between epochs
# Out:
# Epochs: 100%|███████████████████████████████████████████████| 64/64 [01:31<00:00,  1.44s/epoch, loss=0.222, lr=0.00025]

# %% [markdown]
# ## Evaluation

# %%
_ = model.eval()

# %% [markdown]
# ### Parameters

# %%
parameters = sum(p.numel() for p in model.parameters())
parameters
# Out:
# 268289

# %% [markdown]
# ### Speed

# %%
theta, x = next(iter(train_loader))
batches = 2 ** 10

start = torch.cuda.Event(enable_timing=True)
end = torch.cuda.Event(enable_timing=True)

start.record()

with torch.no_grad():
    for _ in range(batches):
        y = model.embedding(x)
        _ = model(theta, y)

end.record()

torch.cuda.synchronize()

seconds = start.elapsed_time(end) * 1e-3

speed = batches / seconds
speed
# Out:
# 2298.70787891609

# %% [markdown]
# ### Corner plot

# %%
theta = torch.tensor([0.3517, -0.0883, -1.4778, 1.6406, -1.9085]).cuda()
x = sim(theta)
y = model.embedding(x)

# %%
sigma = 0.05 * (sim.upper - sim.lower)

sampler = LRESampler(sim.log_prob, sim.prior, x, batch_size=2 ** 12, sigma=sigma)
thetas = torch.cat([t.cpu() for t in sampler(2 ** 13, burn=2 ** 12, skip=2 ** 4)])

# %%
hists = np.ndarray((5, 5), dtype=object)

for i in range(5):
    for j in range(i + 1):
        mask = torch.tensor([k in [i, j] for k in range(5)])
        
        sampler = LRESampler(model[mask], sim.marginal_prior(mask), y, batch_size=2 ** 12)
        hists[i, j] = sampler.grid(100, sim.lower[mask], sim.upper[mask]).cpu().numpy().T

# %%
bounds = (sim.lower.cpu().numpy(), sim.upper.cpu().numpy())

fig = corner(
    thetas.numpy(),
    smooth=2.,
    bounds=bounds,
    labels=sim.labels,
    legend='Likelihood (MCMC)',
    markers=[theta.cpu().numpy()],
)

fig = corner(
    hists,
    smooth=2.,
    bounds=bounds,
    legend='AMNRE',
    figure=fig,
)

# %% [markdown]
# ## Save

# %%
writer.add_hparams(
    hparam_dict={
        'simulator': 'SLCP',
        'embedding': 'Flatten',
        'model': 'AMNRE',
        'layers': 5,
        'neurons_per_layer': 256,
        'activation': 'ELU',
        'epochs': 64,
        'optimizer': 'AdamW',
        'learning_rate': 1e-3,
        'weight_decay': 1e-3,
        'scheduler': 'ReduceLROnPlateau',
        'gamma': 0.5,
        'patience': 7,
        'gradient_clip': 1.,
    },
    metric_dict={
        'parameters': parameters,
        'batches_per_second': speed,
    },
)
